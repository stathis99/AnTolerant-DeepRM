# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
#cost_data_low = pd.read_csv('cost_data_high.csv')
slowdown_data = pd.read_csv('data/slow_down_lr_curve.csv')


# Display the first few rows of the dataframe
print(slowdown_data.head())
# Out:
#    slow_down_lr_curve
# 0            3.842818
# 1            3.874322
# 2            3.759916
# 3            3.693656
# 4            3.647959

# %%
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(slowdown_data.index,slowdown_data, )

# Adding titles and labels
plt.title('slowdown')
plt.xlabel('Index')
plt.ylabel('Cost Data')

# Show the plot
plt.grid(True)
plt.show()

# %%
rew = pd.read_csv('data/mean_rew_lr_curve.csv')
rew
# Out:
#      mean_rew_lr_curve
# 0          -170.399668
# 1          -175.098324
# 2          -164.012282
# 3          -174.942110
# 4          -158.373826
# ..                 ...
# 994         -74.449405
# 995         -73.871266
# 996         -74.187034
# 997         -73.485048
# 998         -73.871683
#
# [999 rows x 1 columns]

# %%
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(rew.index,rew, marker='o')

# Adding titles and labels
plt.title('slowdown')
plt.xlabel('Index')
plt.ylabel('Cost Data')

# Show the plot
plt.grid(True)
plt.show()

# %%
not_exe = pd.read_csv('data/all_avg_not_exec.csv')
not_exe
# Out:
#      all_avg_not_exe
# 0                  1
# 1                  2
# 2                  2
# 3                  1
# 4                  1
# ..               ...
# 994                2
# 995                2
# 996                2
# 997                2
# 998                2
#
# [999 rows x 1 columns]

# %%
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(not_exe.index,not_exe, marker='o')

# Adding titles and labels
plt.title('slowdown')
plt.xlabel('Index')
plt.ylabel('Cost Data')

# Show the plot
plt.grid(True)
plt.show()

# %%
not_exe = pd.read_csv('data/cost_data.csv')
not_exe
# Out:
#      cost_data
# 0        121.0
# 1        101.0
# 2        105.0
# 3        106.0
# 4        119.0
# ..         ...
# 994       72.0
# 995       80.0
# 996       82.0
# 997       82.0
# 998       88.0
#
# [999 rows x 1 columns]

# %%
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(not_exe.index,not_exe, marker='o')

# Adding titles and labels
plt.title('slowdown')
plt.xlabel('Index')
plt.ylabel('Cost Data')

# Show the plot
plt.grid(True)
plt.show()
