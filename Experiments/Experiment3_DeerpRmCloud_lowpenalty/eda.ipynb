# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
#cost_data_low = pd.read_csv('cost_data_high.csv')
slowdown_data = pd.read_csv('data/slow_down_lr_curve.csv')


# Display the first few rows of the dataframe
print(slowdown_data.head())
# Out:
#    slow_down_lr_curve
# 0            3.842818
# 1            3.886878
# 2            3.805062
# 3            3.711782
# 4            3.722811

# %%
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(slowdown_data.index,slowdown_data, marker='o')

# Adding titles and labels
plt.title('slowdown')
plt.xlabel('Index')
plt.ylabel('Cost Data')

# Show the plot
plt.grid(True)
plt.show()

# %%
rew = pd.read_csv('data/mean_rew_lr_curve.csv')
rew
# Out:
#      mean_rew_lr_curve
# 0          -213.104668
# 1          -217.722477
# 2          -214.584451
# 3          -217.785080
# 4          -224.037872
# ..                 ...
# 494        -144.095805
# 495        -137.718297
# 496        -136.274045
# 497        -146.401423
# 498        -141.191858
#
# [499 rows x 1 columns]

# %%
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(rew.index,rew, marker='o')

# Adding titles and labels
plt.title('slowdown')
plt.xlabel('Index')
plt.ylabel('Cost Data')

# Show the plot
plt.grid(True)
plt.show()
